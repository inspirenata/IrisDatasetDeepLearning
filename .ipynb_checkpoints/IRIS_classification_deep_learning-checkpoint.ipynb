# %% [markdown]
# **This is a detailed notebook with Iris dataset and deep learning. I hope it will be helpful and if yes, please vote up! Thank you :-)**

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns #vizualization
import matplotlib.pyplot as plt #vizualization
from sklearn.datasets import load_iris

#from subprocess import check_output
#print(check_output(["ls", "../input"]).decode("utf8"))

# %%
iris = pd.read_csv("../Downloads/Iris.csv")
iris.head(5)
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.1+ KB

# %%
#from sklearn.datasets import load_iris
    
#iris = load_iris()
#iris.target[[10, 25, 50]]
#list(iris.target_names)

# %% [markdown]
# Firstly let's load the dataset as a DateFrame, show the first 5 rows of the dataset and check the data in case of any nulls:

# %% [markdown]
# There is no nulls so it is quite a clean dataset which can be processed.
# Now we are going to explore more information about columns and unique types of irises:

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ## Exploratory analysis - vizualization

# %% [markdown]
# We are going to use very convinient tool to vizualize data and dependencies between inputs, pairplot:

# %%
sns.pairplot(data=iris[iris.columns[1:6]], hue='Species')
plt.show()

# %% [markdown]
# We could not repeat this graph, but I think it would be usefull to notice that we see a clear correlation between Petal features and type of species.

# %%
fig = iris[iris.Species=='Iris-setosa'].plot(kind='scatter', x='PetalLengthCm', y='PetalWidthCm', color='red', label='Setosa')
iris[iris.Species=='Iris-versicolor'].plot(kind='scatter', x='PetalLengthCm', y='PetalWidthCm', color='green', label='Versicolor', ax=fig)
iris[iris.Species=='Iris-virginica'].plot(kind='scatter', x='PetalLengthCm', y='PetalWidthCm', color='yellow', label='Virginica', ax=fig)
fig.set_xlabel("Petal Length")
fig.set_ylabel("Petal Width")
fig.set_title("Petal length depending on Width")
plt.show()

# %% [markdown]
# Lets build a heatmap with input as the correlation matrix calculted by * iris.corr()*

# %%
plt.figure(figsize=(8,5)) 
sns.heatmap(iris.corr(),annot=True,cmap='cubehelix_r') 
plt.show()

# %% [markdown]
# The Petal Width and Length are highly correlated, what we can not say about Sepal Width and Length.
# Now let's build an Andrews curve:

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
from pandas.tools import plotting
plotting.andrews_curves(iris.drop("Id", axis=1), "Species")
plt.show()
# Out:
# C:\Users\Nataliya\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.andrews_curves' is deprecated, import 'pandas.plotting.andrews_curves' instead.

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# We firstly drop out unecessary column, axis=1. Then process normalization for features vector values and check it with showing first 5 lines:

# %%
iris.drop('Id',axis=1, inplace=True) #
df_norm = iris[iris.columns[0:4]].apply(lambda x:(x - x.min())/(x.max() - x.min()))
df_norm.sample(n=5)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 34       0.166667      0.458333       0.084746      0.000000
# 45       0.138889      0.416667       0.067797      0.083333
# 86       0.666667      0.458333       0.627119      0.583333
# 1        0.166667      0.416667       0.067797      0.041667
# 37       0.166667      0.458333       0.084746      0.000000

# %% [markdown]
# Encoding Species labels for use as a target in Neural Network and concatenating feature vectors and target vector in one.

# %%
target = iris[['Species']].replace(iris['Species'].unique(), [0,1,2])
df = pd.concat([df_norm, target], axis=1)
df.sample(n=5)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 1         0.166667      0.416667       0.067797      0.041667        0
# 81        0.333333      0.166667       0.457627      0.375000        1
# 103       0.555556      0.375000       0.779661      0.708333        2
# 0         0.222222      0.625000       0.067797      0.041667        0
# 110       0.611111      0.500000       0.694915      0.791667        2

# %% [markdown]
# ## Train the model

# %%
import keras

from keras.models import Sequential
from keras.layers import Dense

from sklearn.preprocessing import StandardScaler, LabelBinarizer
# Out:
# C:\Users\Nataliya\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# Selecting the target as **y**, and feature vectors as **X** :

# %%
X = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y = df['Species']

X = StandardScaler().fit_transform(X)
y = LabelBinarizer().fit_transform(y)

# %% [markdown]
# Dividing data into train set and test set. We will do it 80/20.

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 101)

# %%
model = Sequential()
model.add(Dense( 4, input_dim=4, activation = 'relu'))
model.add(Dense( units = 15, activation= 'relu'))
model.add(Dense( units = 19, activation= 'relu'))
model.add(Dense( units = 10, activation= 'relu'))
model.add(Dense( units = 3, activation= 'softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
history = model.fit(x_train, y_train, epochs = 120, validation_data = (x_test, y_test))
# Out:
# Train on 120 samples, validate on 30 samples
# Epoch 1/120
# 120/120 [==============================] - 3s 22ms/step - loss: 1.0805 - acc: 0.3000 - val_loss: 1.0718 - val_acc: 0.2333
# Epoch 2/120
# 120/120 [==============================] - 0s 298us/step - loss: 1.0561 - acc: 0.3333 - val_loss: 1.0493 - val_acc: 0.2667
# Epoch 3/120
# 120/120 [==============================] - 0s 333us/step - loss: 1.0337 - acc: 0.3583 - val_loss: 1.0276 - val_acc: 0.3333
# Epoch 4/120
# 120/120 [==============================] - 0s 367us/step - loss: 1.0111 - acc: 0.3667 - val_loss: 1.0067 - val_acc: 0.3667
# Epoch 5/120
# 120/120 [==============================] - 0s 300us/step - loss: 0.9899 - acc: 0.4083 - val_loss: 0.9853 - val_acc: 0.3667
# Epoch 6/120
# 120/120 [==============================] - 0s 333us/step - loss: 0.9678 - acc: 0.4583 - val_loss: 0.9640 - val_acc: 0.5000
# Epoch 7/120
# 120/120 [==============================] - 0s 433us/step - loss: 0.9458 - acc: 0.5083 - val_loss: 0.9421 - val_acc: 0.5000
# Epoch 8/120
# 120/120 [==============================] - 0s 400us/step - loss: 0.9216 - acc: 0.5667 - val_loss: 0.9200 - val_acc: 0.5333
# Epoch 9/120
# 120/120 [==============================] - ETA: 0s - loss: 0.8529 - acc: 0.781 - 0s 366us/step - loss: 0.8983 - acc: 0.6167 - val_loss: 0.8975 - val_acc: 0.5667
# Epoch 10/120
# 120/120 [==============================] - 0s 333us/step - loss: 0.8732 - acc: 0.6750 - val_loss: 0.8745 - val_acc: 0.5667
# Epoch 11/120
# 120/120 [==============================] - 0s 267us/step - loss: 0.8484 - acc: 0.7167 - val_loss: 0.8515 - val_acc: 0.5667
# Epoch 12/120
# 120/120 [==============================] - 0s 400us/step - loss: 0.8241 - acc: 0.7333 - val_loss: 0.8283 - val_acc: 0.6667
# Epoch 13/120
# 120/120 [==============================] - 0s 333us/step - loss: 0.7973 - acc: 0.7750 - val_loss: 0.8055 - val_acc: 0.7667
# Epoch 14/120
# 120/120 [==============================] - 0s 300us/step - loss: 0.7743 - acc: 0.8250 - val_loss: 0.7830 - val_acc: 0.7667
# Epoch 15/120
# 120/120 [==============================] - 0s 400us/step - loss: 0.7493 - acc: 0.8667 - val_loss: 0.7606 - val_acc: 0.8000
# Epoch 16/120
# 120/120 [==============================] - 0s 300us/step - loss: 0